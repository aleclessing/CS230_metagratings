# %%
from predict_tca import *
from evaluate import predictWithInterpolation

# %%
hr_eps, lr_fields, hr_fields = dataloader.MetaGratingDataLoader(return_hres=True, lr_data_filename='data/metanet_lr_data_downsamp16.npy')[11]

net = torch.load('models/model_pde_tca_run6.pth')

sr_fields = predict_img(net=net, lr_img=lr_fields, hr_eps=hr_eps, device='cpu')
plot_hr_lr_sr(hr_fields, lr_fields, sr_fields, int_data=predictWithInterpolation(lr_fields, 8))
# Out:
# torch.Size([1, 64, 256]) torch.Size([1, 2, 4, 16])

# %%
#Show epsilon Grid

# %%
plt.imshow(hr_eps)
